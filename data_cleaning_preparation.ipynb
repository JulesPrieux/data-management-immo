# %%
import pandas as pd
import numpy as np
from multiprocessing.pool import ThreadPool
from threading import Thread

# %%
# Downloading the data
data = {}

URLS = [("2018", "https://static.data.gouv.fr/resources/demandes-de-valeurs-foncieres/20221017-145753/valeursfoncieres-2018.txt"),
        ("2019", "https://static.data.gouv.fr/resources/demandes-de-valeurs-foncieres/20221017-150616/valeursfoncieres-2019.txt"),
        ("2020", "https://static.data.gouv.fr/resources/demandes-de-valeurs-foncieres/20221017-151136/valeursfoncieres-2020.txt"),
        ("2021", "https://static.data.gouv.fr/resources/demandes-de-valeurs-foncieres/20221017-151704/valeursfoncieres-2021.txt"),
        ("Q12022", "https://static.data.gouv.fr/resources/demandes-de-valeurs-foncieres/20221017-152027/valeursfoncieres-2022-s1.txt")]

# %%
# Async download data for a quicker result.
def download_data(year: str, url: str):
    return year, pd.read_csv(url, sep='|')
    
with ThreadPool(len(URLS)) as pool:
    results = pool.starmap_async(download_data, URLS)
    for result in results.get():
        year = result[0]
        dataframe = result[1]
        data[year] = dataframe
# Out:
# /var/folders/fj/8pmdh2z120lbtvdmmc2407th0000gn/T/ipykernel_76863/2757997852.py:3: DtypeWarning: Columns (18,23,24,26,28,31,33,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   return year, pd.read_csv(url, sep='|')
# /var/folders/fj/8pmdh2z120lbtvdmmc2407th0000gn/T/ipykernel_76863/2757997852.py:3: DtypeWarning: Columns (18,23,24,26,28,31,33,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   return year, pd.read_csv(url, sep='|')
# /var/folders/fj/8pmdh2z120lbtvdmmc2407th0000gn/T/ipykernel_76863/2757997852.py:3: DtypeWarning: Columns (14,18,23,24,26,28,29,31,32,33,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   return year, pd.read_csv(url, sep='|')
# /var/folders/fj/8pmdh2z120lbtvdmmc2407th0000gn/T/ipykernel_76863/2757997852.py:3: DtypeWarning: Columns (14,18,23,24,26,28,29,31,33,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   return year, pd.read_csv(url, sep='|')
# /var/folders/fj/8pmdh2z120lbtvdmmc2407th0000gn/T/ipykernel_76863/2757997852.py:3: DtypeWarning: Columns (18,23,24,26,28,30,31,33,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   return year, pd.read_csv(url, sep='|')

# %%
# Check that all dataframes have the same structure.
columns = [set(df.columns) for df in data.values()]

from itertools import groupby

def all_equal(iterable):
    g = groupby(iterable)
    return next(g, True) and not next(g, False)

all_equal(columns)
# Out:
# True

# %%
# Create one dataframe:
dataframes = list(data.values())
df = dataframes[0]
for next_dataframe in dataframes[1:]:
    df = pd.concat([df, next_dataframe])
display(df)
# Out:
#          Code service sages  Reference document  1 Articles CGI  \
# 0                       NaN                 NaN             NaN
# 1                       NaN                 NaN             NaN
# 2                       NaN                 NaN             NaN
# 3                       NaN                 NaN             NaN
# 4                       NaN                 NaN             NaN
# ...                     ...                 ...             ...
# 1429088                 NaN                 NaN             NaN
# 1429089                 NaN                 NaN             NaN
# 1429090                 NaN                 NaN             NaN
# 1429091                 NaN                 NaN             NaN
# 1429092                 NaN                 NaN             NaN
#
#          2 Articles CGI  3 Articles CGI  4 Articles CGI  5 Articles CGI  \
# 0                   NaN             NaN             NaN             NaN
# 1                   NaN             NaN             NaN             NaN
# 2                   NaN             NaN             NaN             NaN
# 3                   NaN             NaN             NaN             NaN
# 4                   NaN             NaN             NaN             NaN
# ...                 ...             ...             ...             ...
# 1429088             NaN             NaN             NaN             NaN
# 1429089             NaN             NaN             NaN             NaN
# 1429090             NaN             NaN             NaN             NaN
# 1429091             NaN             NaN             NaN             NaN
# 1429092             NaN             NaN             NaN             NaN
#
#          No disposition Date mutation Nature mutation  ...  \
# 0                     1    03/01/2018           Vente  ...
# 1                     1    03/01/2018           Vente  ...
# 2                     1    04/01/2018           Vente  ...
# 3                     1    04/01/2018           Vente  ...
# 4                     1    04/01/2018           Vente  ...
# ...                 ...           ...             ...  ...
# 1429088               1    21/06/2022           Vente  ...
# 1429089               1    21/06/2022           Vente  ...
# 1429090               1    30/06/2022           Vente  ...
# 1429091               1    10/02/2022    Adjudication  ...
# 1429092               1    29/04/2022           Vente  ...
#
#         Surface Carrez du 5eme lot  Nombre de lots Code type local  \
# 0                              NaN               1             3.0
# 1                              NaN               2             2.0
# 2                              NaN               0             1.0
# 3                              NaN               0             1.0
# 4                              NaN               0             1.0
# ...                            ...             ...             ...
# 1429088                        NaN               2             3.0
# 1429089                        NaN               1             3.0
# 1429090                        NaN               1             2.0
# 1429091                        NaN               1             3.0
# 1429092                        NaN               1             3.0
#
#           Type local Identifiant local Surface reelle bati  \
# 0         Dépendance               NaN                 0.0
# 1        Appartement               NaN                73.0
# 2             Maison               NaN               163.0
# 3             Maison               NaN                51.0
# 4             Maison               NaN               163.0
# ...              ...               ...                 ...
# 1429088   Dépendance               NaN                 0.0
# 1429089   Dépendance               NaN                 0.0
# 1429090  Appartement               NaN                15.0
# 1429091   Dépendance               NaN                 0.0
# 1429092   Dépendance               NaN                 0.0
#
#          Nombre pieces principales Nature culture Nature culture speciale  \
# 0                              0.0            NaN                     NaN
# 1                              4.0            NaN                     NaN
# 2                              4.0              S                     NaN
# 3                              2.0             AG                    JARD
# 4                              4.0             AG                    JARD
# ...                            ...            ...                     ...
# 1429088                        0.0            NaN                     NaN
# 1429089                        0.0            NaN                     NaN
# 1429090                        1.0            NaN                     NaN
# 1429091                        0.0            NaN                     NaN
# 1429092                        0.0            NaN                     NaN
#
#          Surface terrain
# 0                    NaN
# 1                    NaN
# 2                  949.0
# 3                  420.0
# 4                  420.0
# ...                  ...
# 1429088              NaN
# 1429089              NaN
# 1429090              NaN
# 1429091              NaN
# 1429092              NaN
#
# [16272181 rows x 43 columns]

# %%
# Export to .parquet to have a smaller filesize and avoid repeated downloading.
df.to_csv("downloaded_data.csv")
del df
# Out:
# /var/folders/fj/8pmdh2z120lbtvdmmc2407th0000gn/T/ipykernel_76863/1275080020.py:5: DtypeWarning: Columns (15,19,24,25,27,29,30,31,32,33,34,42) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("downloaded_data.csv")

# %%
# Read the data and use a sample to study it, free the memory after.
df = pd.read_csv("downloaded_data.csv")
sample = df.sample(1_000_000).copy()
del df
# Out:
# /var/folders/fj/8pmdh2z120lbtvdmmc2407th0000gn/T/ipykernel_66595/645220393.py:2: DtypeWarning: Columns (15,19,24,25,27,29,30,31,32,33,34,42) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("downloaded_data.csv")

# %%
# Explore the data
display(sample.columns)
display(sample.info())
# Out:
# Index(['Unnamed: 0', 'Code service sages', 'Reference document',
#        '1 Articles CGI', '2 Articles CGI', '3 Articles CGI', '4 Articles CGI',
#        '5 Articles CGI', 'No disposition', 'Date mutation', 'Nature mutation',
#        'Valeur fonciere', 'No voie', 'B/T/Q', 'Type de voie', 'Code voie',
#        'Voie', 'Code postal', 'Commune', 'Code departement', 'Code commune',
#        'Prefixe de section', 'Section', 'No plan', 'No Volume', '1er lot',
#        'Surface Carrez du 1er lot', '2eme lot', 'Surface Carrez du 2eme lot',
#        '3eme lot', 'Surface Carrez du 3eme lot', '4eme lot',
#        'Surface Carrez du 4eme lot', '5eme lot', 'Surface Carrez du 5eme lot',
#        'Nombre de lots', 'Code type local', 'Type local', 'Identifiant local',
#        'Surface reelle bati', 'Nombre pieces principales', 'Nature culture',
#        'Nature culture speciale', 'Surface terrain'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000000 entries, 3501462 to 4543916
# Data columns (total 44 columns):
#  #   Column                      Non-Null Count    Dtype
# ---  ------                      --------------    -----
#  0   Unnamed: 0                  1000000 non-null  int64
#  1   Code service sages          0 non-null        float64
#  2   Reference document          0 non-null        float64
#  3   1 Articles CGI              0 non-null        float64
#  4   2 Articles CGI              0 non-null        float64
#  5   3 Articles CGI              0 non-null        float64
#  6   4 Articles CGI              0 non-null        float64
#  7   5 Articles CGI              0 non-null        float64
#  8   No disposition              1000000 non-null  int64
#  9   Date mutation               1000000 non-null  object
#  10  Nature mutation             1000000 non-null  object
#  11  Valeur fonciere             989319 non-null   object
#  12  No voie                     611357 non-null   float64
#  13  B/T/Q                       44653 non-null    object
#  14  Type de voie                592915 non-null   object
#  15  Code voie                   991131 non-null   object
#  16  Voie                        991113 non-null   object
#  17  Code postal                 991090 non-null   float64
#  18  Commune                     1000000 non-null  object
#  19  Code departement            1000000 non-null  object
#  20  Code commune                1000000 non-null  int64
#  21  Prefixe de section          44506 non-null    float64
#  22  Section                     999961 non-null   object
#  23  No plan                     1000000 non-null  int64
#  24  No Volume                   2560 non-null     object
#  25  1er lot                     315179 non-null   object
#  26  Surface Carrez du 1er lot   87796 non-null    object
#  27  2eme lot                    77115 non-null    object
#  28  Surface Carrez du 2eme lot  24389 non-null    object
#  29  3eme lot                    13330 non-null    object
#  30  Surface Carrez du 3eme lot  2568 non-null     object
#  31  4eme lot                    4426 non-null     object
#  32  Surface Carrez du 4eme lot  666 non-null      object
#  33  5eme lot                    2025 non-null     object
#  34  Surface Carrez du 5eme lot  266 non-null      object
#  35  Nombre de lots              1000000 non-null  int64
#  36  Code type local             569421 non-null   float64
#  37  Type local                  569421 non-null   object
#  38  Identifiant local           0 non-null        float64
#  39  Surface reelle bati         568762 non-null   float64
#  40  Nombre pieces principales   568762 non-null   float64
#  41  Nature culture              680367 non-null   object
#  42  Nature culture speciale     43703 non-null    object
#  43  Surface terrain             680367 non-null   float64
# dtypes: float64(15), int64(5), object(24)
# memory usage: 343.3+ MB
# None

# %%
# Check for empty columns or columns with lots of Nans. Don't drop Data above the lot and lot size because we will reformat them later.
def drop_empty_cols(df):
    len_df = len(df)
    for col in df:
        if "lot" in col:
            continue
        if df[col].isna().sum() / len_df > 0.5:
            print(f"{col} have too much missing data. Dropping it.")
            df = df.drop(col, axis=1)
    return df

sample = drop_empty_cols(sample)
display(sample.isna().sum())
# Out:
# Code service sages have too much missing data. Dropping it.
# Reference document have too much missing data. Dropping it.
# 1 Articles CGI have too much missing data. Dropping it.
# 2 Articles CGI have too much missing data. Dropping it.
# 3 Articles CGI have too much missing data. Dropping it.
# 4 Articles CGI have too much missing data. Dropping it.
# 5 Articles CGI have too much missing data. Dropping it.
# B/T/Q have too much missing data. Dropping it.
# Prefixe de section have too much missing data. Dropping it.
# No Volume have too much missing data. Dropping it.
# Identifiant local have too much missing data. Dropping it.
# Nature culture speciale have too much missing data. Dropping it.
# Unnamed: 0                         0
# No disposition                     0
# Date mutation                      0
# Nature mutation                    0
# Valeur fonciere                10681
# No voie                       388643
# Type de voie                  407085
# Code voie                       8869
# Voie                            8887
# Code postal                     8910
# Commune                            0
# Code departement                   0
# Code commune                       0
# Section                           39
# No plan                            0
# 1er lot                       684821
# Surface Carrez du 1er lot     912204
# 2eme lot                      922885
# Surface Carrez du 2eme lot    975611
# 3eme lot                      986670
# Surface Carrez du 3eme lot    997432
# 4eme lot                      995574
# Surface Carrez du 4eme lot    999334
# 5eme lot                      997975
# Surface Carrez du 5eme lot    999734
# Nombre de lots                     0
# Code type local               430579
# Type local                    430579
# Surface reelle bati           431238
# Nombre pieces principales     431238
# Nature culture                319633
# Surface terrain               319633
# dtype: int64

# %%
# Dropping the columns that don't carry useful information.
def drop_useless_columns(df):
    to_drop = ["Unnamed: 0", "Nature mutation", "No voie", "Voie", "Commune", "No disposition", "Code type local"]
    return df.drop(to_drop, axis=1)

sample = drop_useless_columns(sample)
display(sample)
# Out:
#          Date mutation Valeur fonciere Type de voie Code voie  Code postal  \
# 3501462     03/04/2019      1265000,00           BD      0376       6210.0
# 14739727    31/12/2021      1950802,60          RUE      0018      97250.0
# 9144049     20/11/2020       335000,00          RUE      0485      62136.0
# 6110660     01/03/2019       179000,00          RUE      3460      77500.0
# 4471476     04/03/2019       150000,00          RUE      0253      33770.0
# ...                ...             ...          ...       ...          ...
# 1348119     12/03/2018        70000,00          NaN      B054      39210.0
# 10330507    28/02/2020             NaN          NaN      B007      95340.0
# 13586791    12/07/2021        50000,00           PL      0030      72610.0
# 1163089     20/12/2018       780000,00          NaN      B046      34480.0
# 4543916     19/07/2019       217000,00           AV      4620      34070.0
#
#          Code departement  Code commune Section  No plan 1er lot  ...  \
# 3501462                 6            79      BR      396     NaN  ...
# 14739727              972            25       C      493     NaN  ...
# 9144049                62           502      CN       36     NaN  ...
# 6110660                77           108      AR      545   281.0  ...
# 4471476                33           498      AS      216     NaN  ...
# ...                   ...           ...     ...      ...     ...  ...
# 1348119                39           317      ZI       47     NaN  ...
# 10330507               95           487      ZA       40     NaN  ...
# 13586791               72           355       A      107     NaN  ...
# 1163089                34            44       G      363     NaN  ...
# 4543916                34           172      DV      629    98.0  ...
#
#          4eme lot Surface Carrez du 4eme lot 5eme lot  \
# 3501462       NaN                        NaN      NaN
# 14739727      NaN                        NaN      NaN
# 9144049       NaN                        NaN      NaN
# 6110660       NaN                        NaN      NaN
# 4471476       NaN                        NaN      NaN
# ...           ...                        ...      ...
# 1348119       NaN                        NaN      NaN
# 10330507      NaN                        NaN      NaN
# 13586791      NaN                        NaN      NaN
# 1163089       NaN                        NaN      NaN
# 4543916       NaN                        NaN      NaN
#
#          Surface Carrez du 5eme lot Nombre de lots   Type local  \
# 3501462                         NaN              0       Maison
# 14739727                        NaN              0  Appartement
# 9144049                         NaN              0       Maison
# 6110660                         NaN              1   Dépendance
# 4471476                         NaN              0          NaN
# ...                             ...            ...          ...
# 1348119                         NaN              0          NaN
# 10330507                        NaN              0          NaN
# 13586791                        NaN              0   Dépendance
# 1163089                         NaN              0          NaN
# 4543916                         NaN              1          NaN
#
#          Surface reelle bati Nombre pieces principales Nature culture  \
# 3501462                205.0                       7.0              S
# 14739727                45.0                       1.0              J
# 9144049                219.0                       7.0              S
# 6110660                  0.0                       0.0            NaN
# 4471476                  NaN                       NaN             AG
# ...                      ...                       ...            ...
# 1348119                  NaN                       NaN              T
# 10330507                 NaN                       NaN              T
# 13586791                 0.0                       0.0              S
# 1163089                  NaN                       NaN              T
# 4543916                  NaN                       NaN            NaN
#
#           Surface terrain
# 3501462             500.0
# 14739727           2000.0
# 9144049             755.0
# 6110660               NaN
# 4471476             769.0
# ...                   ...
# 1348119            1732.0
# 10330507           1245.0
# 13586791            580.0
# 1163089            3100.0
# 4543916               NaN
#
# [1000000 rows x 25 columns]

# %%
# Checking % of missing values.
sample.isna().sum() / len(sample)
# Out:
# Date mutation                 0.000000
# Valeur fonciere               0.010681
# Type de voie                  0.407085
# Code voie                     0.008869
# Code postal                   0.008910
# Code departement              0.000000
# Code commune                  0.000000
# Section                       0.000039
# No plan                       0.000000
# 1er lot                       0.684821
# Surface Carrez du 1er lot     0.912204
# 2eme lot                      0.922885
# Surface Carrez du 2eme lot    0.975611
# 3eme lot                      0.986670
# Surface Carrez du 3eme lot    0.997432
# 4eme lot                      0.995574
# Surface Carrez du 4eme lot    0.999334
# 5eme lot                      0.997975
# Surface Carrez du 5eme lot    0.999734
# Nombre de lots                0.000000
# Type local                    0.430579
# Surface reelle bati           0.431238
# Nombre pieces principales     0.431238
# Nature culture                0.319633
# Surface terrain               0.319633
# dtype: float64

# %%
# Drop the columns that have too much missing values or can't be treated.
sample = sample.drop(["Type de voie", "Surface Carrez du 5eme lot", "Type local", "Surface reelle bati", 
                      "Nombre pieces principales", "Nature culture", "Surface terrain"], axis=1)
display(sample)
# Out:
#          Date mutation Valeur fonciere Code voie  Code postal  \
# 3501462     03/04/2019      1265000,00      0376       6210.0
# 14739727    31/12/2021      1950802,60      0018      97250.0
# 9144049     20/11/2020       335000,00      0485      62136.0
# 6110660     01/03/2019       179000,00      3460      77500.0
# 4471476     04/03/2019       150000,00      0253      33770.0
# ...                ...             ...       ...          ...
# 1348119     12/03/2018        70000,00      B054      39210.0
# 10330507    28/02/2020             NaN      B007      95340.0
# 13586791    12/07/2021        50000,00      0030      72610.0
# 1163089     20/12/2018       780000,00      B046      34480.0
# 4543916     19/07/2019       217000,00      4620      34070.0
#
#          Code departement  Code commune Section  No plan 1er lot  \
# 3501462                 6            79      BR      396     NaN
# 14739727              972            25       C      493     NaN
# 9144049                62           502      CN       36     NaN
# 6110660                77           108      AR      545   281.0
# 4471476                33           498      AS      216     NaN
# ...                   ...           ...     ...      ...     ...
# 1348119                39           317      ZI       47     NaN
# 10330507               95           487      ZA       40     NaN
# 13586791               72           355       A      107     NaN
# 1163089                34            44       G      363     NaN
# 4543916                34           172      DV      629    98.0
#
#          Surface Carrez du 1er lot 2eme lot Surface Carrez du 2eme lot  \
# 3501462                        NaN      NaN                        NaN
# 14739727                       NaN      NaN                        NaN
# 9144049                        NaN      NaN                        NaN
# 6110660                        NaN      NaN                        NaN
# 4471476                        NaN      NaN                        NaN
# ...                            ...      ...                        ...
# 1348119                        NaN      NaN                        NaN
# 10330507                       NaN      NaN                        NaN
# 13586791                       NaN      NaN                        NaN
# 1163089                        NaN      NaN                        NaN
# 4543916                        NaN      NaN                        NaN
#
#          3eme lot Surface Carrez du 3eme lot 4eme lot  \
# 3501462       NaN                        NaN      NaN
# 14739727      NaN                        NaN      NaN
# 9144049       NaN                        NaN      NaN
# 6110660       NaN                        NaN      NaN
# 4471476       NaN                        NaN      NaN
# ...           ...                        ...      ...
# 1348119       NaN                        NaN      NaN
# 10330507      NaN                        NaN      NaN
# 13586791      NaN                        NaN      NaN
# 1163089       NaN                        NaN      NaN
# 4543916       NaN                        NaN      NaN
#
#          Surface Carrez du 4eme lot 5eme lot  Nombre de lots
# 3501462                         NaN      NaN               0
# 14739727                        NaN      NaN               0
# 9144049                         NaN      NaN               0
# 6110660                         NaN      NaN               1
# 4471476                         NaN      NaN               0
# ...                             ...      ...             ...
# 1348119                         NaN      NaN               0
# 10330507                        NaN      NaN               0
# 13586791                        NaN      NaN               0
# 1163089                         NaN      NaN               0
# 4543916                         NaN      NaN               1
#
# [1000000 rows x 18 columns]

# %%
# Convert non numeric fields to float
def convert_to_float(value: str):
    if pd.isna(value):
        return
    value = str(value)
    try:
        return float(value.replace(',', '.'))
    except ValueError:
        return 

sample[["1er lot", "Surface Carrez du 1er lot", 
       "2eme lot", "Surface Carrez du 2eme lot",
       "3eme lot", "Surface Carrez du 3eme lot",
       "4eme lot", "Surface Carrez du 4eme lot",
       "5eme lot", "Valeur fonciere"]] = sample[["1er lot", "Surface Carrez du 1er lot", 
       "2eme lot", "Surface Carrez du 2eme lot",
       "3eme lot", "Surface Carrez du 3eme lot",
       "4eme lot", "Surface Carrez du 4eme lot",
       "5eme lot", "Valeur fonciere"]].applymap(convert_to_float)

# Convert missing values to 0 fort Surface fields.
sample[["1er lot", "Surface Carrez du 1er lot", 
       "2eme lot", "Surface Carrez du 2eme lot",
       "3eme lot", "Surface Carrez du 3eme lot",
       "4eme lot", "Surface Carrez du 4eme lot",
       "5eme lot"]] = sample[["1er lot", "Surface Carrez du 1er lot", 
       "2eme lot", "Surface Carrez du 2eme lot",
       "3eme lot", "Surface Carrez du 3eme lot",
       "4eme lot", "Surface Carrez du 4eme lot",
       "5eme lot"]].fillna(0)

# Drop the remaining Nan values:
display(sample)
# Out:
#          Date mutation  Valeur fonciere Code voie  Code postal  \
# 3501462     03/04/2019        1265000.0      0376       6210.0
# 14739727    31/12/2021        1950802.6      0018      97250.0
# 9144049     20/11/2020         335000.0      0485      62136.0
# 6110660     01/03/2019         179000.0      3460      77500.0
# 4471476     04/03/2019         150000.0      0253      33770.0
# ...                ...              ...       ...          ...
# 1348119     12/03/2018          70000.0      B054      39210.0
# 10330507    28/02/2020              NaN      B007      95340.0
# 13586791    12/07/2021          50000.0      0030      72610.0
# 1163089     20/12/2018         780000.0      B046      34480.0
# 4543916     19/07/2019         217000.0      4620      34070.0
#
#          Code departement  Code commune Section  No plan  1er lot  \
# 3501462                 6            79      BR      396      0.0
# 14739727              972            25       C      493      0.0
# 9144049                62           502      CN       36      0.0
# 6110660                77           108      AR      545    281.0
# 4471476                33           498      AS      216      0.0
# ...                   ...           ...     ...      ...      ...
# 1348119                39           317      ZI       47      0.0
# 10330507               95           487      ZA       40      0.0
# 13586791               72           355       A      107      0.0
# 1163089                34            44       G      363      0.0
# 4543916                34           172      DV      629     98.0
#
#           Surface Carrez du 1er lot  2eme lot  Surface Carrez du 2eme lot  \
# 3501462                         0.0       0.0                         0.0
# 14739727                        0.0       0.0                         0.0
# 9144049                         0.0       0.0                         0.0
# 6110660                         0.0       0.0                         0.0
# 4471476                         0.0       0.0                         0.0
# ...                             ...       ...                         ...
# 1348119                         0.0       0.0                         0.0
# 10330507                        0.0       0.0                         0.0
# 13586791                        0.0       0.0                         0.0
# 1163089                         0.0       0.0                         0.0
# 4543916                         0.0       0.0                         0.0
#
#           3eme lot  Surface Carrez du 3eme lot  4eme lot  \
# 3501462        0.0                         0.0       0.0
# 14739727       0.0                         0.0       0.0
# 9144049        0.0                         0.0       0.0
# 6110660        0.0                         0.0       0.0
# 4471476        0.0                         0.0       0.0
# ...            ...                         ...       ...
# 1348119        0.0                         0.0       0.0
# 10330507       0.0                         0.0       0.0
# 13586791       0.0                         0.0       0.0
# 1163089        0.0                         0.0       0.0
# 4543916        0.0                         0.0       0.0
#
#           Surface Carrez du 4eme lot  5eme lot  Nombre de lots
# 3501462                          0.0       0.0               0
# 14739727                         0.0       0.0               0
# 9144049                          0.0       0.0               0
# 6110660                          0.0       0.0               1
# 4471476                          0.0       0.0               0
# ...                              ...       ...             ...
# 1348119                          0.0       0.0               0
# 10330507                         0.0       0.0               0
# 13586791                         0.0       0.0               0
# 1163089                          0.0       0.0               0
# 4543916                          0.0       0.0               1
#
# [1000000 rows x 18 columns]

# %%
# Check for missing values again:
sample.isna().sum() / len(sample)
# Out:
# Date mutation                 0.000000
# Valeur fonciere               0.010681
# Code voie                     0.008869
# Code postal                   0.008910
# Code departement              0.000000
# Code commune                  0.000000
# Section                       0.000039
# No plan                       0.000000
# 1er lot                       0.000000
# Surface Carrez du 1er lot     0.000000
# 2eme lot                      0.000000
# Surface Carrez du 2eme lot    0.000000
# 3eme lot                      0.000000
# Surface Carrez du 3eme lot    0.000000
# 4eme lot                      0.000000
# Surface Carrez du 4eme lot    0.000000
# 5eme lot                      0.000000
# Nombre de lots                0.000000
# dtype: float64

# %%
# Drop missing values, we still have many datapoints.
sample = sample.dropna()
display(sample)
# Out:
#          Date mutation  Valeur fonciere Code voie  Code postal  \
# 3501462     03/04/2019        1265000.0      0376       6210.0
# 14739727    31/12/2021        1950802.6      0018      97250.0
# 9144049     20/11/2020         335000.0      0485      62136.0
# 6110660     01/03/2019         179000.0      3460      77500.0
# 4471476     04/03/2019         150000.0      0253      33770.0
# ...                ...              ...       ...          ...
# 14840995    25/02/2021         270000.0      4614      75018.0
# 1348119     12/03/2018          70000.0      B054      39210.0
# 13586791    12/07/2021          50000.0      0030      72610.0
# 1163089     20/12/2018         780000.0      B046      34480.0
# 4543916     19/07/2019         217000.0      4620      34070.0
#
#          Code departement  Code commune Section  No plan  1er lot  \
# 3501462                 6            79      BR      396      0.0
# 14739727              972            25       C      493      0.0
# 9144049                62           502      CN       36      0.0
# 6110660                77           108      AR      545    281.0
# 4471476                33           498      AS      216      0.0
# ...                   ...           ...     ...      ...      ...
# 14840995               75           118      BW      117     22.0
# 1348119                39           317      ZI       47      0.0
# 13586791               72           355       A      107      0.0
# 1163089                34            44       G      363      0.0
# 4543916                34           172      DV      629     98.0
#
#           Surface Carrez du 1er lot  2eme lot  Surface Carrez du 2eme lot  \
# 3501462                        0.00       0.0                         0.0
# 14739727                       0.00       0.0                         0.0
# 9144049                        0.00       0.0                         0.0
# 6110660                        0.00       0.0                         0.0
# 4471476                        0.00       0.0                         0.0
# ...                             ...       ...                         ...
# 14840995                      24.02      60.0                         0.0
# 1348119                        0.00       0.0                         0.0
# 13586791                       0.00       0.0                         0.0
# 1163089                        0.00       0.0                         0.0
# 4543916                        0.00       0.0                         0.0
#
#           3eme lot  Surface Carrez du 3eme lot  4eme lot  \
# 3501462        0.0                         0.0       0.0
# 14739727       0.0                         0.0       0.0
# 9144049        0.0                         0.0       0.0
# 6110660        0.0                         0.0       0.0
# 4471476        0.0                         0.0       0.0
# ...            ...                         ...       ...
# 14840995       0.0                         0.0       0.0
# 1348119        0.0                         0.0       0.0
# 13586791       0.0                         0.0       0.0
# 1163089        0.0                         0.0       0.0
# 4543916        0.0                         0.0       0.0
#
#           Surface Carrez du 4eme lot  5eme lot  Nombre de lots
# 3501462                          0.0       0.0               0
# 14739727                         0.0       0.0               0
# 9144049                          0.0       0.0               0
# 6110660                          0.0       0.0               1
# 4471476                          0.0       0.0               0
# ...                              ...       ...             ...
# 14840995                         0.0       0.0               2
# 1348119                          0.0       0.0               0
# 13586791                         0.0       0.0               0
# 1163089                          0.0       0.0               0
# 4543916                          0.0       0.0               1
#
# [980402 rows x 18 columns]

# %%
# Export to csv for data exploration:
sample.to_csv("cleaned_data.csv")
